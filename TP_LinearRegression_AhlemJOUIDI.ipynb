# %%
fn1 = "ahlem"
ln1 = "jouidi"
filename = "_".join(map(lambda s: s.strip().lower(),
["SD-TSIA204_lab2", ln1, fn1])) + ".ipynb"

# %%
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd 
import sys
import matplotlib 
import numpy as np
import math
from numpy import linalg as LA
import random
from scipy.stats import norm
# Enable inline plotting
# %matplotlib inline

# %%
### Question 1
Location = 'data_dm3.csv'
df = pd.read_csv(Location, header=None)
df
# Out:
#           0         1         2         3         4         5         6    \
# 0   -1.298173 -0.162249  1.223379  1.355554  1.080171  0.634979  0.298741
# 1    0.166951 -0.338060 -0.618867  0.759366  1.134281 -0.536844 -0.075120
# 2   -0.416177 -0.205659 -1.282226  1.675500  1.523746  0.192029 -0.235840
# 3    0.867184 -0.398667  0.093501  0.025971  1.852099  0.789774  0.801775
# 4    1.193282 -0.936980 -0.725039  0.766078  0.223489 -1.584622  1.146866
# 5    1.513286  0.072830  1.243039 -0.368609 -0.564998 -1.736720 -0.441544
# 6   -0.501760  0.191544 -0.225878 -0.240506  1.350852 -1.253936  1.319458
# 7   -1.012528 -1.383290  0.686803  2.146420  1.255864  0.806962  0.137307
# 8    0.532639  1.691226 -0.008375 -1.478906  1.278352 -0.176214 -0.806066
# 9   -0.537216 -0.128677 -0.815059 -1.273897 -0.985841  1.021629 -0.956690
# 10   0.281095  0.892597 -0.604375  1.740050 -1.973232  0.613186  1.138497
# 11   0.207881 -0.133698 -0.781764  0.275791 -0.576272  0.791383  0.435898
# ...

# %%
Y= np.array(df.iloc[:,-1]) 
X= np.array(df.iloc[:,:-1])  

print("The number of exploratory variable is ", np.shape(X)[1])
print("The number of the observations is ", np.shape(X)[0])
# Out:
# The number of exploratory variable is  210
# The number of the observations is  442

# %% [markdown]
# # Question 2

# %%
df.describe()
# Out:
#                 0             1             2             3             4    \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   7.535450e-19 -1.507090e-17  5.494599e-20 -7.284269e-18  8.288995e-18
# std    1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00
# min   -3.149247e+00 -2.862871e+00 -3.057543e+00 -2.856903e+00 -3.102347e+00
# 25%   -6.707870e-01 -7.128394e-01 -7.160981e-01 -6.715474e-01 -6.732232e-01
# 50%    3.819503e-02  6.217421e-02  4.739406e-02  6.565749e-05 -6.111315e-03
# 75%    6.748497e-01  6.244547e-01  6.975121e-01  6.881971e-01  7.026457e-01
# max    2.547051e+00  2.567177e+00  2.965824e+00  3.057612e+00  3.173713e+00
#
#                 5             6             7             8             9    \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.712762e-17  1.971776e-17  8.540177e-18  1.029845e-17  4.018907e-18
# ...

# %% [markdown]
# as we can see in the second row (mean), the mean of all the exploratary variables is 0 and in the third row (std) the standar variation is 1. So our data is centered and normalized

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)

rand_variables = random.sample(range(0, X.shape[1]), 4)

rand_X = []
for i in range(4):
    rand_X.append(df.iloc[:, rand_variables[i]])

rand_X.append(Y)
rand_X = pd.DataFrame(rand_X).T
rand_X.columns = ['var 1','var 2','var 3','var 4','Y']
print(rand_X.head())
sns.set(style="ticks", color_codes=True)

sns.pairplot(rand_X)
plt.show()
# Out:
#       var 1     var 2     var 3     var 4      Y
# 0  1.080171  1.223379  0.341585  1.517710  151.0
# 1  1.134281 -0.618867 -0.548755 -0.045326   75.0
# 2  1.523746 -1.282226 -0.200168 -0.700610  141.0
# 3  1.852099  0.093501  1.148394  0.019174  206.0
# 4  0.223489 -0.725039  0.550898  0.807625  135.0

# %% [markdown]
# # Question 3

# %%
from sklearn.model_selection import train_test_split
    
X_train, X_test, y_train, y_test = train_test_split(X,Y ,test_size=0.2)
print("The size of the test variables is ",np.shape(X_test))
print("The size of the train variables is ",np.shape(X_train))
# Out:
# The size of the test variables is  (89, 210)
# The size of the train variables is  (353, 210)

# %% [markdown]
# # Question 4

# %%
cov=np.cov(X_train.transpose())
np.shape(cov)
eg_values, eg_vectors=LA.eig(cov)
eg_values=np.array(eg_values)
eg_vectors=np.array(eg_vectors)
index = np.argsort(-np.abs(eg_values))
eg_values_sorted=-np.sort(-eg_values)

eg_vectors_sorted = np.array(eg_vectors)[index]

plt.plot(np.arange(0,210,1),eg_values_sorted)

plt.ylabel("Eignvalues")
plt.title("The eigenvalues of the covariance matrix")
# Out:
# C:\Users\ahlem jouidi\Anaconda3\lib\site-packages\numpy\core\numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# Text(0.5,1,'The eigenvalues of the covariance matrix')

# %% [markdown]
# # Question 5

# %%
#X_train60= X_train[:,:60]
eg_vectors60= eg_vectors_sorted[:60]
X_PCA= np.matmul(X_train,np.real(eg_vectors60).T)

from sklearn.linear_model import LinearRegression
reg_PCA = LinearRegression(fit_intercept=True).fit(X_PCA, y_train)

plt.scatter(range(60),reg_PCA.coef_)

plt.title("PCA before OLS method")
plt.ylabel("Regression coefficient")
# Out:
# Text(0,0.5,'Regression coefficient')

# %%
reg_OLS= LinearRegression(fit_intercept=True).fit(X_train, y_train)

plt.title("OLS method")
plt.ylabel("Regression coefficient")
plt.scatter(range(210),reg_OLS.coef_)

# %%
_ = plt.scatter(range(reg_PCA.coef_.size) ,reg_PCA.coef_,label="Coeffs With PCA")
_ = plt.scatter(range(reg_OLS.coef_.size) ,reg_OLS.coef_, label="Coeffs Without PCA")
_ = plt.title("OLS coeffs")
_ = plt.xlabel('Regression coefficient index')
_ = plt.ylabel("Coefficient value")
_= plt.legend(loc="upper left", bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# We can see that there are too many zero coefficients.
# We can notice that the range of the coefficients is smaller when using PCA. So using PCA will help us reduce the complexity of our model.

# %% [markdown]
# # Question 6

# %%
print("The intercept of the OLS method is", reg_OLS.intercept_)
print("The intercept of the PCA before OLS method is", reg_PCA.intercept_)
print("The mean value of the train set is", np.mean(y_train))
# Out:
# The intercept of the OLS method is 153.68803116147308
# The intercept of the PCA before OLS method is 153.03158468889558
# The mean value of the train set is 153.81303116147308

# %% [markdown]
# The two intercepts are almost equal which shows that taking the 60 most relevant covariates yields almost the same results. PCA help as to reduce the shape of data without loosing information.

# %%
from sklearn import preprocessing
X_PCA= X_PCA- np.mean(X_PCA, axis=0)
X_PCA_std = X_PCA / np.std(X_PCA, axis=0)
##normalized_X_PCA = preprocessing.normalize(X_PCA)

reg_PCA_normalized = LinearRegression(fit_intercept=True).fit(X_PCA_std , y_train)
reg_PCA_normalized.intercept_
# Out:
# 153.81303116147308

# %% [markdown]
# We see clearly that the intercept is equal to the average of Y on the train
# set.
# ==> As prooved in the course that the intercept of the OLS when the data is centered and normolized is equal to the mean of the ytrain

# %% [markdown]
# # Question 7

# %%
import seaborn as sns

X_test_PCA= np.matmul(X_test,np.real(eg_vectors60).T)
y_predicted_PCA= reg_PCA.predict(X_test_PCA)

y_predicted_OLS= reg_OLS.predict(X_test)


residual_OLS = np.abs ( y_predicted_OLS -  y_test ) 
residual_PCA = np.abs ( y_predicted_PCA -  y_test ) 

plt.figure()
plt.scatter ( range ( len (residual_OLS )), residual_OLS ) 
plt.title('Residuals with OLS')

plt.figure()
plt.scatter ( range ( len (residual_PCA )), residual_PCA ) 
plt.title('Residuals with PCA before OLS')


plt.figure()
plt.scatter ( range ( len (residual_OLS )), residual_OLS ,label="Residual without PCA")
plt.scatter ( range ( len (residual_PCA )), residual_PCA, label="Residual with PCA" ) 
_ = plt.title("OLS residuals")
_ = plt.xlabel('Test observation index')
_ = plt.ylabel("Residual value")
_ = plt.legend(loc="upper left", bbox_to_anchor=(1,1))
plt.show()

# %%
_= plt.hist(residual_OLS, bins = 8)
_ = plt.title("Residuals without PCA before OLS")
_ = plt.xlabel('Test observation index')
_ = plt.ylabel("Residual value")
plt.show()

_= plt.hist(residual_PCA, bins = 8)
_ = plt.title("Residuals with PCA")
_ = plt.xlabel('Test observation index')
_ = plt.ylabel("Residual value")
plt.show()

# %%
from sklearn.metrics import r2_score

R2_PCA= r2_score(y_test, y_predicted_PCA)
R2_classical_OLS= r2_score(y_test, y_predicted_OLS)
print( " The R2 coefficient for PCA before OLS method is = ", R2_PCA)
print( " The R2 coefficient for OLS classical mehtod is = ",  R2_classical_OLS)
# Out:
#  The R2 coefficient for PCA before OLS method is =  0.3122821478868544
#  The R2 coefficient for OLS classical mehtod is =  0.18887877879572645

# %%
from sklearn.metrics import mean_squared_error

n=y_test.shape[0]
Risk_PCA = mean_squared_error (y_predicted_PCA, y_test )/n
Risk_OLS = mean_squared_error (y_predicted_OLS,y_test  )/n

print( " The prediction risk for the classical OLS method = ", Risk_OLS)
print( " The prediction risk for the PCA before OLS method = ", Risk_PCA)
# Out:
#  The prediction risk for the classical OLS method =  54.249190149846406
#  The prediction risk for the PCA before OLS method =  45.99575939258315

# %% [markdown]
# # Question 8

# %%
X_aug = np.column_stack((np.ones((X_train.shape[0], 1 )), X_train)) 

p = X_aug.shape[1]
n = X_aug.shape[0]

test = np.zeros((p,p))
pval_mem = np.zeros(p)
pval = np.zeros((p,p))
resids = y_train

var_sel = []
var_remain = list(range(p))
in_test = []

regr = LinearRegression(fit_intercept = False)

for k in range(p): 
    resids_mem = np.zeros((p,n))

    for i in var_remain:
        xtmp = X_aug [:,[i]]
        regr.fit(xtmp , resids)
        
        # Compute (x'x)
        xx = np.sum( X_aug [:,[i]] ** 2 )    
        resids_mem [i,:] = regr.predict(xtmp) - resids
        sigma2_tmp = np.sum (resids_mem [i,:] ** 2) / xx
        test[k,i] = np.sqrt(n) * np.abs(regr.coef_) / (np.sqrt( sigma2_tmp )) 
        pval[k,i] =   2 * (1 - norm.cdf(test[k,i]))
        
    #### Seperate in two vectors, the list of the selected variables and the others
    best_var = np.argmax(test[k,:])
    var_sel.append(best_var)
    resids = resids_mem[best_var,:]
    pval_mem [k] = pval[k,best_var]
    var_remain = np.setdiff1d(var_remain,var_sel)

# %%
print("Selected variables (In order of selection): " , np.array(var_sel))
# Out:
# Selected variables (In order of selection):  [  0  59 124 130  14 209 134 168   6  88 136  41 191 127 152  27  25 167
#  129  16 175   8 156  38 166 178 203  94  80 176  35 162 187 164  81 188
#  189 121  34  30  46 137  68 119  72  21 177  71  24 149  86  39 123  76
#   65  10 153 159 169 195 173 117 116  48 100  60  74  67  58 105 138  42
#  144  57 131  43  91 143   3  95 109  69 200 110 183  85 201 139  82  20
#   45  17 148 186 204 141  77  79 205   2  83 135 132 103  33 113  96 150
#   89  18 154  70   1  54  93 196  99 118 172  63 208  61  56  32   4  92
#  108 170  29 122 102   9 182  19  62 210  26 157 194   5  87  47 133  37
#   40 198  52 165  51  36 128  66  15  97  23  22 115 192  73 184 181  12
#  185 107  31 190 206 114 160 171  75 104  50 163 126 111   7 125 179 202
#   55  44 180 140  84 174  49 147 146 106 197 142  78  28 199 193 151 112
#  120 158 207  64 161  90 101 145 155  11  53  13  98]

# %%
def foo(s1):
    return "step %s" % s1

fig = plt.figure()
for k in range(3): 
    lab_tmp = foo(k)
    plt.plot(np.arange(p),test[k,:], '-o',label = lab_tmp)
    plt.axis(xmin = -.5,xmax = 20,ymin = -1)
plt.legend(loc=1)
plt.title("values of the t-stat at each steps")
plt.xlabel("features")
plt.show()

# %% [markdown]
# # Question 9

# %%
fig2 = plt.figure() 
for k in range(3): 
    plt.plot(np.arange(50),pval_mem [:50], 'o')
    plt.plot([-0.5,50],[.1,.1],color = "blue" )
    plt.axis(xmin = -.5,xmax = 50,ymin = -.03)
plt.title("plot of the pvalues")
plt.xlabel("steps")
plt.show()

# %%
print("Les variables sélectionnées (dans l'ordre): " , 
      np.array(var_sel)[pval_mem<.1])
# Out:
# Les variables sélectionnées (dans l'ordre):  [  0  59 124 130  14 209 134 168   6  88 136  41]

# %% [markdown]
# # Question 10

# %%
sel = np.array(var_sel)[pval_mem<.1]
k = np.count_nonzero(sel)
sel = sel[1:]
X_learn_forward = X_aug[:,sel]

regr = LinearRegression()
regr.fit(X_learn_forward , y_train)


pred_forward = regr.predict(X_test [:,sel])
risk_forward = mean_squared_error (pred_forward,y_test  )/n
print('the risk forward is', risk_forward)
# Out:
# the risk forward is 26.036691868243732

# %% [markdown]
# Based on first the random split of the data, in this case we got a lower risk using forward variable selection. So it performs better than PCA and it consider y when reducing dimension.

# %% [markdown]
# # Question 11

# %%
#/* Calculate the risk of the residual */
def calculate_risk(residual):
    return residual.var() + residual.mean()**2

# %%
from sklearn.model_selection import KFold
k = 4
kf = KFold(k, True, 1)
X_train= np.array(X_train)
y_train = np.array(y_train)
kfolds = np.array(list(kf.split(X_train))) #convert generator(kf.split()) to list 
for train, test in kf.split(X_train):
    print('the train shape is : %s, the train test is : ' ,(X_train[train].shape, X_train[test].shape))
# Out:
# the train shape is : %s, the train test is :  ((264, 210), (89, 210))
# the train shape is : %s, the train test is :  ((265, 210), (88, 210))
# the train shape is : %s, the train test is :  ((265, 210), (88, 210))
# the train shape is : %s, the train test is :  ((265, 210), (88, 210))

# %% [markdown]
# # Question 12

# %%
# lambdas = 10**np.linspace(-4,4,500) // too big 
lambdas = 10**np.linspace(-4,2,500)
p= X_train.shape[1]

estimated_risk = []
for lmbd in lambdas:
    error = 0
    ridge = Ridge(alpha=lmbd)
    for i in range(k):
        train, test = kfolds[i, :]
        X_fold_train = X_train[train]
        y_fold_train = y_train[train]
        X_fold_test = X_train[test]
        y_fold_test = y_train[test]
        n = y_fold_test.shape[0]
        
#         theta_ridge = np.matmul(np.linalg.inv(lmbd * np.identity(p) + np.matmul(X_fold_train.T, X_fold_train)), 
#                                 np.matmul(X_fold_train.T, y_fold_train))
        
#         y_predicted_fold = np.matmul(X_fold_test, theta_ridge)
#         error_avg = error_avg + mean_squared_error(y_predicted_fold, y_fold_test )/n
        
        ridge.fit(X_fold_train, y_fold_train)
        y_predicted_fold = ridge.predict(X_fold_test)
        error = error + calculate_risk(y_fold_test - y_predicted_fold)/n
   
    estimated_risk.append(error/k)

_ = plt.figure()    
_ = plt.plot(lambdas, estimated_risk)
_ = plt.xlabel('alpha value')
_ = plt.ylabel('Risk')
_ = plt.title('CV ridge: risk = f(alpha)')

n = X_test.shape[0]
lambda_ridge = lambdas[np.argmin(estimated_risk)]
_ = plt.axvline(x= lambda_ridge, color = 'r', linestyle = '--', label = 'optimal')
plt.show()

# %%
ridge = Ridge(alpha=lambda_ridge)
ridge.fit(X_train, y_train)
y_predicted_ridge = ridge.predict(X_test)
Risk_ridge = calculate_risk(y_test - y_predicted_ridge)/n
print("The optimal value of alpha is {:.5f}.\nThe corresponding risk on the test set is {:.3f}"
      .format(lambda_ridge, Risk_ridge))
# Out:
# The optimal value of alpha is 46.06029.
# The corresponding risk on the test set is 44.407

# %% [markdown]
# # Question 13

# %%
from sklearn.linear_model import LassoCV
X_train, X_test, y_train, y_test = train_test_split(X,Y ,test_size=0.2)
model = LassoCV(cv=4).fit(X_train, y_train)

m_log_alphas = -np.log10(model.alphas_)

plt.figure()

plt.plot(m_log_alphas, model.mse_path_, ':')
plt.plot(m_log_alphas, model.mse_path_.mean(axis=-1), 'k',
         label='Average across the folds', linewidth=2)
plt.axvline(-np.log10(model.alpha_), linestyle='--', color='k',
            label='alpha: CV estimate')

plt.legend()

plt.xlabel('-log(alpha)')
plt.ylabel('Mean square error')
plt.title('Mean square error on each fold: coordinate descent')
plt.axis('tight')

print('The CV estimated alpha is', model.alpha_)
print('risk is ', mean_squared_error(y_test, model.predict(X_test))/n)
# Out:
# The CV estimated alpha is 4.9101866076837455
# risk is  38.607850530097956

# %% [markdown]
# # Question 14

# %%
print('The number of selected variables by the LASSO is', np.size(model.coef_.nonzero()) )
print('The selected variables by the LASSO are', model.coef_.nonzero())

print('The coefficients of the selected variables are')
u= pd.Series(model.coef_ , index=df.iloc[:,:-1].columns )
u.shape
nb_var=0
for i in u :
    if i!=0 :
        print (i)
# Out:
# The number of selected variables by the LASSO is 16
# The selected variables by the LASSO are (array([ 13,  17,  28,  53,  58, 112, 117, 123, 129, 130, 135, 155, 167,
#        174, 176, 209], dtype=int64),)
# The coefficients of the selected variables are
# 2.5686957697562325
# -0.36154952293382525
# 0.6606360650867907
# -0.12976054873014622
# 23.958861329352768
# 2.0716250775991067
# 0.016879783393853195
# 22.099434661932243
# -2.9297491615339237
# -1.6552841900319262
# -0.5242426959464481
# -0.057415057604455165
# 12.294515563112514
# -4.100534488928273
# 0.6437348726944746
# -0.5240060579370576

# %%
X_train_lasso=[]
X_train_lasso=X_train[:,model.coef_.nonzero()[0] ]
print('The new shape of covariate matrix is', np.shape(X_train_lasso) )

reg_OLS_LASSO = LinearRegression(fit_intercept=True).fit(X_train_lasso, y_train)
plt.scatter(range(np.size(model.coef_.nonzero())),reg_OLS_LASSO.coef_)

plt.title("Least-square LASSO method")
plt.ylabel("Regression coefficient")
# Out:
# The new shape of covariate matrix is (353, 16)
# Text(0,0.5,'Regression coefficient')

# %% [markdown]
# # Question 15

# %% [markdown]
# I have choosed the Polynomial method as method of non-linear
# regression

# %%
from sklearn.preprocessing import PolynomialFeatures

X1=X_train[:,model.coef_.nonzero()[0]]   ## We will use selected variables by the LASSO method
X_tst=X_test[:,model.coef_.nonzero()[0]]
polynomial_features= PolynomialFeatures(degree=2)
x_poly = polynomial_features.fit_transform(X1)
x_test = polynomial_features.fit_transform(X_tst)

model = LinearRegression()
model.fit(x_poly, y_train)
y_chap = model.predict(x_test)
risk = (1/n) * np.linalg.norm(y_chap - y_test)**2
print('The risk is ',risk)
# Out:
# The risk is  4763.192537800649

# %% [markdown]
# The non linear regression method have worse risk than the linear methods.
